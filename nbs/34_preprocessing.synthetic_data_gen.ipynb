# %% [markdown]
# # Creation synthetic data based on single pin

# %% [markdown]
# > Synthetic data generation

# %%
#| default_exp preprocessing.synthetic_data_gen

# %%
#| hide
# %load_ext autoreload
# %autoreload 2

# %%
#| export
from cv_tools.core import *

# %%
#| hide
import nbdev; nbdev.nbdev_export('34_preprocessing.synthetic_data_gen.ipynb')
